# %%
# Chapter 2 Python Basics

#  this is a comment
print ("Hello")     #this is also a comment
print( "Lena Li")
type ("Hello")
num1 = 5    #storing an interer into a variable
num2 = 8.4  #storing a float into a variaable
print(num1, num2)   #multiples items are print using commas

#storing a boolean into a variable
switch = True
print (switch)

# storing strings into a variable
name = 'John Smith'
fav_number = '9'
print(name, fav_number)

# using 2 variables to create another variable
result= num1 + num2
print (result)

#using operators on Numerical variables
result += 1
print (result)
result *= num1
print (result)

#Exercise
x = 3
y = 10
result = x+y
print ('3+10=',result)

Width= 13.66
Height= 245.54
Area = Width*Height
print (Area)

#using the addition operator without variables
name = "John" + " " + "Smith"
print (name)
#using ... with variables
first_name= "john"
last_name= "smith"
full_name= first_name + " " + last_name
print(full_name)

#Injecting variables using the format method
name = "John"
print ("Hello {}" .format(name))
print ("Hello {}, you are {} years old!" .format(name,28))

#f Strings
print (f"Hello {name}")

#using indexes to print each element
word = "Hello"
print ( word[0])
print ( word [1])
print ( word [-1])
#splicing string
print ( word[0:2])
#start:stop:step, increments of 2 between 0 and 5 
print ( word[0:5:2])

#Exercise
a= 23
b= 4.5
c= False
d= "John"
print(a, b, c, d)

name = "Lena"
sport = "pilates"
program = "python"
print ( f"{name}'s favourite sport is {sport}")
print ( f"{name} is working on {program} programming!")

name = "john smith"
print ( name.title())
print ( name. lower())
print ( name. upper())

#replacing characters
words= "Hello there!"
print ( words.replace("!", ","))

#replacing white space with strip
name = "    John    "
print( name.strip( ))
print( name.lstrip(" "))
print( name.rstrip(" "))

# converting string into a list of words
s = "These words are separated by spaces"
print ( s.split(" "))

#Thursday exercise
s = "uppercase"
print ( s .upper())
name="$$John Smith"
print( name .strip("$"))
print( name .lstrip("$"))
help(" ".strip)
# Out:
# Hello
# Lena Li
# 5 8.4
# True
# John Smith 9
# 13.4
# 14.4
# 72.0
# 3+10= 13
# 3354.0764
# John Smith
# john smith
# Hello John
# Hello John, you are 28 years old!
# Hello John
# H
# e
# o
# He
# Hlo
# 23 4.5 False John
# Lena's favourite sport is pilates
# Lena is working on python programming!
# John Smith
# john smith
# JOHN SMITH
# Hello there,
# John
# John
#     John
# ['These', 'words', 'are', 'separated', 'by', 'spaces']
# UPPERCASE
# John Smith
# John Smith
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
#create a product and price for three items
p1_name, p1_price = "Books", 49.95
p2_name, p2_price = "Computer", 579.99
p3_name, p3_price = "Monitor", 124.89

# create a company name and information
company_name = "coding temple, inc."
company_address = "283 Franklin St."
company_city = "Boston, MA"

# declare ending message
message = "Thanks for shopping with us today!"

# create a top border
print("*" * 50)
print( "\t\t{}" .format( company_name.title()))
print( "\t\t{}" .format(company_address))
print( "\t\t{}" .format(company_city))
print( "=" * 50)

#displaying product infor
print( "\tProduct Name\tProduct Price")
print( "\t{}\t\t${}" .format(p1_name.title(), p1_price))
print ( "\t{}\t${}" .format(p2_name.title(), p2_price))
print( "\t{}\t\t${}" .format(p3_name .title(), p3_price))

# print a line between sections
print('=' * 50)

print( "\t\t\tTotal")
# Calculate total price and print out
total = p1_price + p2_price + p3_price 
print( "\t\t\t${}" .format(total))

# print a line between sections
print ("=" * 50)

# output thank you message
print( "\n\t{}\n" .format(message))

# create a bottom border
print ("*" *50)
# Out:
# **************************************************
# 		Coding Temple, Inc.
# 		283 Franklin St.
# 		Boston, MA
# ...
# 	Product Name	Product Price
# 	Books		$49.95
# 	Computer	$579.99
# 	Monitor		$124.89
# ...
# 			Total
# 			$754.83
# ...
#
# 	Thanks for shopping with us today!
#
# **************************************************

# %%
print ("Hell0")
# Out:
# Hell0
