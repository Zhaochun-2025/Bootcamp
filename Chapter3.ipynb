# %%
#User input and conditionals
num = 5
print( type(num))

# converting a variable from one data type to another
num = "9"
num = float(num)
print( type(num))

# working with user input to perform calculations
ans = "9"
print ( type(ans))
result = 100 + int(ans)
print("100 + {} = {}" .format(ans, result))

ans = float(5)
print("100+ {} = {}" .format(ans, 100 + ans))
#hwk
string = True
print ( type(string))

ans1 = 1 #input("what is....")
ans2 = 2 #input("what is....")
print ("The sum of these two numbers are", ans1+ans2)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 100 + 9 = 109
# 100+ 5.0 = 105.0
# <class 'bool'>
# The sum of these two numbers are 3

# %%
#Tues: if, and, or, in, else
x, y = 5, 10
if x < y:
    print ( "\nx is less than y")

ans = int(5.0)
if ans == 5:
    print ("Yout got it right!")

# using 'and' and 'if statement'
x, y, z = 5, 10, 5
if x < y and x == z:
    print ("Both statements were true")


#using keyword 'or' in an 'if statement'
x, y, z= 5, 10, 5
if x <y or x != z:
    print ('One or both statements were true')

#using keyword 'not' within an'if statement'
flag = False
if not flag:    #same as saying if not true
    print( "Flag is false")

#using keyword 'in' within an 'if statement'
word = "Baseball"
if "b" in word:
    print( "{} contains the character b" .format(word))

#'Not in' within a 'if statement'
word = "Baseball"
if "x" not in  word:
    print("{} does not contain the character x" .format(word))

#hwk
ans = "Test"
if "es" in ans:
    print("{} contains the the letter 'es'" .format(ans))
else:
    print("{} does not contain the letters 'es'" .format(ans))

user_input = "testing"
    # Check if the input ends with "ing" using slicing
if user_input[-3:] == "ing":
    print("That word ends with 'ing'!")
else:
    print("That word does not end with 'ing'.")
# Out:
# x is less than y
# Yout got it right!
# Both statements were true
# One or both statements were true
# Flag is false
# Baseball contains the character b
# Baseball does not contain the character x
# Test contains the the letter 'es'
# That word ends with 'ing'!

# %%
# Wednesday: Elifs and ifs
ans1= input("Enter one of two words that are the same").upper
ans2= input("Enter the other words that are the same").upper
print (ans1, ans2)
if ans1 == ans2:
    print("Both words were the same")
else:
    print("Both words are different words")

ans = 4
if ans < 10:
    print( ans **2)

#elif Statements
x, y = 5, 10
if x > y:
        print("x is greater")
elif x<y:
        print("x is less")

#conditionals within conditions
x, y, z =5, 10 ,5
if x > y:
     print("x is greater than y")
elif x <= y:
     if x ==z:
        print ("x is equal to z")
elif x !=z:
        print("x is not equal to z")


#elif vs if, elif= related statements to an 'if' with one outcome, whereas multiple 'if's are not related
x, y, z = 5, 10, 5
if x < y:
     print("x is less")
if x==z:
     print ("x is equal")

x= 200  #x= input("Provide a number greater or lower than 100")
if x > 100:
     print ("\nx is greater than 100")
elif x < 100:
     print ("\nx is smaller than 100")

x, y = 5, 10
if x > y:
     print("x is greater")
elif x < y:
    print("x is lower")

#Else statements, if not then else (whereas elif is: given/if, then....)
name = "John"
if name == "Jacob":
     print ("Hello Jacob!")
else:
     print("Hello {}" .format(name))

# writing a full conditional state with if, elif, else
name = "John"
if name [0] == "A":
     print("Name starts with an A")
elif name [0] =="B":
     print ("Name starts with a B")
else:
     print( "Name starts with a {}" .format( name[0]))
